# %% [markdown]
# <a href="https://colab.research.google.com/github/l24140373-lang/Analisis-y-visualizacion-de-datos./blob/main/Estad%C3%ADstica_descriptiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Requiered libraries
install.packages("readxl")
library(readxl)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
datos<-read_excel("data.xlsx")
head(datos)
# Out:
#   Helado   Estatura peso     Ingresos Educacion Hijos
# 1 Limón    1.806198 89.95462 1601.832 4         1
# 2 Maracuyá 1.854355 85.18091 1740.319 2         0
# 3 Mora     1.640591 71.52460 1432.034 1         4
# 4 Coco     1.559733 86.17954 2068.077 1         2
# 5 Fresa    1.854728 59.88186 1639.082 1         0
# 6 Mora     1.653885 86.44549 2026.320 2         2

# %%
mean(datos$Estatura)
# Out:
# [1] 1.734004

# %%
apply(as.matrix(datos[,2:4]), 2,mean)
# Out:
#    Estatura        peso    Ingresos
#    1.734004   74.482674 1700.416694

# %%
lapply(datos[,2:4], mean)
# Out:
# $Estatura
# [1] 1.734004
#
# $peso
# [1] 74.48267
#
# $Ingresos
# [1] 1700.417

# %%
unlist(lapply(datos[,2:4], mean)) # unlist -> para no verlo como lista
# Out:
#    Estatura        peso    Ingresos
#    1.734004   74.482674 1700.416694

# %%
median(datos$Estatura)
# Out:
# [1] 1.739476

# %%
apply(as.matrix(datos[,2:4]),2, median)
# Out:
#    Estatura        peso    Ingresos
#    1.739476   74.413605 1713.799500

# %%
unlist(lapply(datos[,2:4], median)) # unlist -> para no verlo como lista
# Out:
#    Estatura        peso    Ingresos
#    1.739476   74.413605 1713.799500

# %%
var(datos$Estatura)
# Out:
# [1] 0.01016447

# %%
sd(datos$peso)
# Out:
# [1] 11.62325

# %%
apply(as.matrix(datos[,2:4]), 2, sd)
# Out:
#   Estatura       peso   Ingresos
#   0.100819  11.623248 291.202692

# %%
unlist(lapply(datos[,2:4], sd)) # unlist -> para no verlo como lista
# Out:
#   Estatura       peso   Ingresos
#   0.100819  11.623248 291.202692

# %%
quantile(datos$Estatura)
# Out:
#       0%      25%      50%      75%     100%
# 1.550751 1.648060 1.739476 1.822418 1.899272

# %% [markdown]
# CONCLUSION: En lo particular me agrada el funcionamiento de github con google colab de manera que facilita el crear respaldos y conservar nuestros archivo de una plataforma a otra , ala vez es mi primera vez realizando este tipo de trabajos por lo cual he aprendido demasiado
